# %% [markdown]
# # TCDF for COVID-19 Time Series Data Analysis

# %% [markdown]
# ## Germany

# %%
# %matplotlib inline
# %run -i "runTCDF.py" --data data/covid-ger.csv --epochs=2000 --kernel_size=10 --hidden_layers=0 --learning_rate=0.001 --optimizer="Adam" --dilation_coefficient=10 --significance=0.5
# Out:
# Arguments: Namespace(cuda=False, data=['data/covid-ger.csv'], dilation_coefficient=10, epochs=2000, ground_truth=None, hidden_layers=0, kernel_size=10, learning_rate=0.001, log_interval=500, optimizer='Adam', plot=False, seed=1111, significance=0.5)
#
#  Dataset:  covid-ger.csv
#
#  Analysis started for target:  allbed_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  ICUbed_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  InvVen_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  admis_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  newICU_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  bedover_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  icuover_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  deaths_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  totdea_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  mobility_composite
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  total_tests
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  confirmed_infections
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  est_infections_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
# ===================Results for covid-ger.csv ==================================
# allbed_mean causes allbed_mean with a delay of 1 time steps.
# ICUbed_mean causes allbed_mean with a delay of 0 time steps.
# allbed_mean causes ICUbed_mean with a delay of 0 time steps.
# ICUbed_mean causes ICUbed_mean with a delay of 1 time steps.
# allbed_mean causes InvVen_mean with a delay of 0 time steps.
# ICUbed_mean causes InvVen_mean with a delay of 0 time steps.
# allbed_mean causes admis_mean with a delay of 0 time steps.
# ICUbed_mean causes admis_mean with a delay of 0 time steps.
# allbed_mean causes newICU_mean with a delay of 0 time steps.
# ICUbed_mean causes newICU_mean with a delay of 0 time steps.
# allbed_mean causes bedover_mean with a delay of 0 time steps.
# ICUbed_mean causes bedover_mean with a delay of 0 time steps.
# allbed_mean causes icuover_mean with a delay of 0 time steps.
# ICUbed_mean causes icuover_mean with a delay of 0 time steps.
# allbed_mean causes deaths_mean with a delay of 0 time steps.
# ICUbed_mean causes deaths_mean with a delay of 0 time steps.
# allbed_mean causes totdea_mean with a delay of 0 time steps.
# ICUbed_mean causes totdea_mean with a delay of 0 time steps.
# allbed_mean causes mobility_composite with a delay of 0 time steps.
# ICUbed_mean causes mobility_composite with a delay of 0 time steps.
# allbed_mean causes total_tests with a delay of 0 time steps.
# ICUbed_mean causes total_tests with a delay of 0 time steps.
# allbed_mean causes confirmed_infections with a delay of 0 time steps.
# ICUbed_mean causes confirmed_infections with a delay of 0 time steps.
# allbed_mean causes est_infections_mean with a delay of 0 time steps.
# ICUbed_mean causes est_infections_mean with a delay of 0 time steps.
# ==================================================================================

# %% [markdown]
# ## Italy

# %%
# %matplotlib inline
# %run -i "runTCDF.py" --data data/covid-it.csv --epochs=2000 --kernel_size=10 --hidden_layers=0 --learning_rate=0.001 --optimizer="Adam" --dilation_coefficient=10 --significance=0.5
# Out:
# Arguments: Namespace(cuda=False, data=['data/covid-it.csv'], dilation_coefficient=10, epochs=2000, ground_truth=None, hidden_layers=0, kernel_size=10, learning_rate=0.001, log_interval=500, optimizer='Adam', plot=False, seed=1111, significance=0.5)
#
#  Dataset:  covid-it.csv
#
#  Analysis started for target:  allbed_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  ICUbed_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  InvVen_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  admis_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  newICU_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  bedover_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  icuover_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  deaths_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  totdea_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  mobility_composite
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  total_tests
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  confirmed_infections
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  est_infections_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
# ===================Results for covid-it.csv ==================================
# allbed_mean causes allbed_mean with a delay of 1 time steps.
# ICUbed_mean causes allbed_mean with a delay of 0 time steps.
# allbed_mean causes ICUbed_mean with a delay of 0 time steps.
# ICUbed_mean causes ICUbed_mean with a delay of 1 time steps.
# allbed_mean causes InvVen_mean with a delay of 0 time steps.
# ICUbed_mean causes InvVen_mean with a delay of 0 time steps.
# allbed_mean causes admis_mean with a delay of 0 time steps.
# ICUbed_mean causes admis_mean with a delay of 0 time steps.
# allbed_mean causes newICU_mean with a delay of 0 time steps.
# ICUbed_mean causes newICU_mean with a delay of 0 time steps.
# allbed_mean causes bedover_mean with a delay of 0 time steps.
# ICUbed_mean causes bedover_mean with a delay of 0 time steps.
# allbed_mean causes icuover_mean with a delay of 0 time steps.
# ICUbed_mean causes icuover_mean with a delay of 0 time steps.
# allbed_mean causes deaths_mean with a delay of 0 time steps.
# ICUbed_mean causes deaths_mean with a delay of 0 time steps.
# allbed_mean causes totdea_mean with a delay of 0 time steps.
# ICUbed_mean causes totdea_mean with a delay of 0 time steps.
# allbed_mean causes mobility_composite with a delay of 0 time steps.
# ICUbed_mean causes mobility_composite with a delay of 0 time steps.
# allbed_mean causes total_tests with a delay of 0 time steps.
# ICUbed_mean causes total_tests with a delay of 0 time steps.
# allbed_mean causes confirmed_infections with a delay of 0 time steps.
# ICUbed_mean causes confirmed_infections with a delay of 0 time steps.
# allbed_mean causes est_infections_mean with a delay of 0 time steps.
# ICUbed_mean causes est_infections_mean with a delay of 0 time steps.
# ==================================================================================

# %% [markdown]
# ## United Stated of America

# %%
# %matplotlib inline
# %run -i "runTCDF.py" --data data/covid-us.csv --epochs=2000 --kernel_size=10 --hidden_layers=0 --learning_rate=0.001 --optimizer="Adam" --dilation_coefficient=10 --significance=0.5
# Out:
# Arguments: Namespace(cuda=False, data=['data/covid-us.csv'], dilation_coefficient=10, epochs=2000, ground_truth=None, hidden_layers=0, kernel_size=10, learning_rate=0.001, log_interval=500, optimizer='Adam', plot=False, seed=1111, significance=0.5)
#
#  Dataset:  covid-us.csv
#
#  Analysis started for target:  allbed_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  ICUbed_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  InvVen_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  admis_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  newICU_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  bedover_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  icuover_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  deaths_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  totdea_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  mobility_composite
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  total_tests
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  confirmed_infections
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
#  Analysis started for target:  est_infections_mean
# Epoch:  1 [0%] 	Loss: nan
# Epoch: 500 [25%] 	Loss: nan
# Epoch: 1000 [50%] 	Loss: nan
# Epoch: 1500 [75%] 	Loss: nan
# Epoch: 2000 [100%] 	Loss: nan
# Potential causes:  [0, 1]
# Validated causes:  [0, 1]
#
# ===================Results for covid-us.csv ==================================
# allbed_mean causes allbed_mean with a delay of 1 time steps.
# ICUbed_mean causes allbed_mean with a delay of 0 time steps.
# allbed_mean causes ICUbed_mean with a delay of 0 time steps.
# ICUbed_mean causes ICUbed_mean with a delay of 1 time steps.
# allbed_mean causes InvVen_mean with a delay of 0 time steps.
# ICUbed_mean causes InvVen_mean with a delay of 0 time steps.
# allbed_mean causes admis_mean with a delay of 0 time steps.
# ICUbed_mean causes admis_mean with a delay of 0 time steps.
# allbed_mean causes newICU_mean with a delay of 0 time steps.
# ICUbed_mean causes newICU_mean with a delay of 0 time steps.
# allbed_mean causes bedover_mean with a delay of 0 time steps.
# ICUbed_mean causes bedover_mean with a delay of 0 time steps.
# allbed_mean causes icuover_mean with a delay of 0 time steps.
# ICUbed_mean causes icuover_mean with a delay of 0 time steps.
# allbed_mean causes deaths_mean with a delay of 0 time steps.
# ICUbed_mean causes deaths_mean with a delay of 0 time steps.
# allbed_mean causes totdea_mean with a delay of 0 time steps.
# ICUbed_mean causes totdea_mean with a delay of 0 time steps.
# allbed_mean causes mobility_composite with a delay of 0 time steps.
# ICUbed_mean causes mobility_composite with a delay of 0 time steps.
# allbed_mean causes total_tests with a delay of 0 time steps.
# ICUbed_mean causes total_tests with a delay of 0 time steps.
# allbed_mean causes confirmed_infections with a delay of 0 time steps.
# ICUbed_mean causes confirmed_infections with a delay of 0 time steps.
# allbed_mean causes est_infections_mean with a delay of 0 time steps.
# ICUbed_mean causes est_infections_mean with a delay of 0 time steps.
# ==================================================================================

# %% [markdown]
# # TCDF for COVID-19 Time Series Data Analysis

# %% [markdown]
# ## Germany

# %%
# %matplotlib inline
# %run -i "runTCDF.py" --data data/covid-ger-extended.csv --epochs=6000 --kernel_size=14 --hidden_layers=0 --learning_rate=0.01 --optimizer="Adam" --dilation_coefficient=14 --significance=0.8 --plot

# %%
# %run -i "runTCDF.py" --data data/covid-ger-extended-trim.csv --epochs=10000 --kernel_size=7 --hidden_layers=0 --learning_rate=0.001 --optimizer="Adam" --dilation_coefficient=7 --significance=0.8 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/covid-ger-extended-trim.csv'], dilation_coefficient=7, epochs=10000, ground_truth=None, hidden_layers=0, kernel_size=7, learning_rate=0.001, log_interval=500, optimizer='Adam', plot=True, seed=1111, significance=0.8)
#
#  Dataset:  covid-ger-extended-trim.csv
#
#  Analysis started for target:  stay_home_states
# Epoch:  1 [0%] 	Loss: 192.669785
# Epoch: 500 [5%] 	Loss: 3.439338
# Epoch: 1000 [10%] 	Loss: 1.277974
# Epoch: 1500 [15%] 	Loss: 0.656663
# Epoch: 2000 [20%] 	Loss: 0.362813
# Epoch: 2500 [25%] 	Loss: 0.249097
# Epoch: 3000 [30%] 	Loss: 0.172213
# Epoch: 3500 [35%] 	Loss: 0.119741
# Epoch: 4000 [40%] 	Loss: 0.101217
# Epoch: 4500 [45%] 	Loss: 0.093519
# Epoch: 5000 [50%] 	Loss: 0.087556
# Epoch: 5500 [55%] 	Loss: 0.083350
# Epoch: 6000 [60%] 	Loss: 0.080513
# Epoch: 6500 [65%] 	Loss: 0.077467
# Epoch: 7000 [70%] 	Loss: 0.075234
# Epoch: 7500 [75%] 	Loss: 0.073491
# Epoch: 8000 [80%] 	Loss: 0.071531
# ...

# %%
# %run -i "runTCDF.py" --data data/covid-ger-extended-trim.csv --epochs=10000 --kernel_size=14 --hidden_layers=0 --learning_rate=0.001 --optimizer="Adam" --dilation_coefficient=14 --significance=0.8 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/covid-ger-extended-trim.csv'], dilation_coefficient=14, epochs=10000, ground_truth=None, hidden_layers=0, kernel_size=14, learning_rate=0.001, log_interval=500, optimizer='Adam', plot=True, seed=1111, significance=0.8)
#
#  Dataset:  covid-ger-extended-trim.csv
#
#  Analysis started for target:  stay_home_states
# Epoch:  1 [0%] 	Loss: 79536.164062
# Epoch: 500 [5%] 	Loss: 101.163429
# Epoch: 1000 [10%] 	Loss: 40.555202
# Epoch: 1500 [15%] 	Loss: 14.658493
# Epoch: 2000 [20%] 	Loss: 8.198459
# Epoch: 2500 [25%] 	Loss: 5.886580

# %% [markdown]
# ## Italy

# %%
# %matplotlib inline
# %run -i "runTCDF.py" --data data/covid-it.csv --epochs=2000 --kernel_size=10 --hidden_layers=0 --learning_rate=0.001 --optimizer="Adam" --dilation_coefficient=10 --significance=0.5

# %% [markdown]
# ## United Stated of America

# %%
# %matplotlib inline
# %run -i "runTCDF.py" --data data/covid-us.csv --epochs=2000 --kernel_size=10 --hidden_layers=0 --learning_rate=0.001 --optimizer="Adam" --dilation_coefficient=10 --significance=0.5
